# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'E:\Proyectos\tibber\data\batch_processing_data\batch1.csv')
df2 = pd.read_csv(r'E:\Proyectos\tibber\data\batch_processing_data\batch2.csv')
df3 = pd.read_csv(r'E:\Proyectos\tibber\data\batch_processing_data\batch3.csv')

# %%
df1.head(100)
# Out:
#                                       id            item   price currency  \
# 0   11111111-1111-1111-1111-111111111111           Pulse  199.99      NOK
# 1   22222222-2222-2222-2222-222222222222     Smart Pulse  249.50      EUR
# 2   33333333-3333-3333-3333-333333333333    Tibber Pulse  299.99      USD
# 3   44444444-4444-4444-4444-444444444444  Energy Monitor  349.99      NOK
# 4   55555555-5555-5555-5555-555555555555    Smart Sensor  189.95      JPY
# 5   66666666-6666-6666-6666-666666666666     Pulse Light  129.99      NOK
# 6   77777777-7777-7777-7777-777777777777   Tibber Energy  399.00      USD
# 7   88888888-8888-8888-8888-888888888888   Tibber Sensor  219.99      NOK
# 8   99999999-9999-9999-9999-999999999999   Tibber Charge  279.50      SEK
# 9   aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa       Pulse Pro  359.99      GBP
# 10  bbbbbbbb-bbbb-bbbb-bbbb-bbbbbbbbbbbb      Pulse Mini  149.99      NOK
# 11  cccccccc-cccc-cccc-cccc-cccccccccccc     SmartCharge  409.50      EUR
# ...

# %%
df2.head(100)
# Out:
#                                      id            item   price currency  \
# 0  11111111-1111-1111-1111-111111111111           Pulse  209.99      NOK
# 1  22222222-2222-2222-2222-222222222222     Smart Pulse  259.50      EUR
# 2  33333333-3333-3333-3333-333333333333    Tibber Pulse  309.99      USD
# 3  44444444-4444-4444-4444-444444444444  Energy Monitor  359.99      NOK
# 4  55555555-5555-5555-5555-555555555555    Smart Sensor  199.95      JPY
# 5  0f0f0f0f-0f0f-0f0f-0f0f-0f0f0f0f0f0f       Pulse Max   99.50      USD
#
#                   created_at                 updated_at  \
# 0  2025-03-01T08:00:00+01:00  2025-03-05T08:05:00+01:00
# 1  2025-03-01T09:15:00+01:00  2025-03-05T09:20:00+01:00
# 2  2025-03-01T10:00:00+01:00  2025-03-05T10:05:00+01:00
# 3  2025-03-01T11:00:00+01:00  2025-03-05T11:10:00+01:00
# 4  2025-03-01T12:00:00+01:00  2025-03-05T12:10:00+01:00
# 5  2025-03-03T12:00:00+01:00  2025-03-04T11:05:00+01:00
#
#             system_timestamp
# ...

# %%
df3.head(100)
# Out:
#                                      id            item   price currency  \
# 0  12345678-1234-1234-1234-123456789abc  Tibber Connect  279.99      EUR
# 1  87654321-4321-4321-4321-cba987654321         Pulse X  409.95      NOK
# 2  abcdefab-cdef-cdef-cdef-abcdefabcdef    SmartPulse X  199.95      JPY
# 3  fedcbafe-dcba-dcba-dcba-fedcbafedcba    Tibber Elite  439.99      NOK
# 4  0f0f0f0f-0f0f-0f0f-0f0f-0f0f0f0f0f0f       Pulse Max  369.50      USD
# 5  aaaaaaaa-0000-0000-0000-000000000001     Tibber Flex  319.99      NOK
# 6  aaaaaaaa-0000-0000-0000-000000000002     Pulse Ultra  459.99      EUR
# 7  aaaaaaaa-0000-0000-0000-000000000003    Smart Energy  389.99      USD
# 8  aaaaaaaa-0000-0000-0000-000000000004    Tibber Spark  279.99      JPY
# 9  aaaaaaaa-0000-0000-0000-000000000005  Pulse Plus Pro  499.99      GBP
#
#                   created_at                 updated_at  \
# 0  2025-03-04T08:00:00+01:00  2025-03-06T08:05:00+01:00
# ...
